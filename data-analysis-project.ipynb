# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Merging 12 months data into a single file.

# %%
df= pd.read_csv("/Users/ravi/Desktop/python/Pandas-Data-Science/SalesAnalysis/Sales_Data/Sales_april_2019.csv")

df.head()

files= [file for file in os.listdir('/Users/ravi/Desktop/python/Pandas-Data-Science/SalesAnalysis/Sales_Data/')]
all_months_data= pd.DataFrame()
for file in files:
    df1= pd.read_csv("/Users/ravi/Desktop/python/Pandas-Data-Science/SalesAnalysis/Sales_Data/"+file)
    all_months_data= pd.concat([all_months_data, df1])
    

all_months_data.head(10)
all_months_data.to_csv("all_data.csv", index= False)

# %% [markdown]
# ### Read In Updated DataFrame

# %%
All_months_data =pd.read_csv("all_data.csv")
all_months_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# ### Clean up the data

# %%
nan_df = all_months_data[all_months_data.isna() .any (axis=1)]
nan_df.head (50)

all_months_data =all_months_data.dropna(how='all')
all_months_data.head ()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# ### Filter Irregular Data

# %%
all_months_data= all_months_data[all_months_data[ 'Order Date'].str [0:2] != 'Or']
all_months_data.head(20)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    295665          Macbook Pro Laptop                1       1700
# 1    295666          LG Washing Machine                1      600.0
# 2    295667        USB-C Charging Cable                1      11.95
# 3    295668            27in FHD Monitor                1     149.99
# 4    295669        USB-C Charging Cable                1      11.95
# 5    295670       AA Batteries (4-pack)                1       3.84
# 6    295671        USB-C Charging Cable                1      11.95
# 7    295672        USB-C Charging Cable                2      11.95
# 8    295673  Bose SoundSport Headphones                1      99.99
# 9    295674      AAA Batteries (4-pack)                4       2.99
# 10   295675        USB-C Charging Cable                2      11.95
# 11   295676             ThinkPad Laptop                1     999.99
# 12   295677       AA Batteries (4-pack)                2       3.84
# 13   295678      AAA Batteries (4-pack)                2       2.99
# 14   295679        USB-C Charging Cable                1      11.95
# 15   295680    Lightning Charging Cable                1      14.95
# 16   295681                Google Phone                1        600
# 17   295681        USB-C Charging Cable                1      11.95
# 18   295681  Bose SoundSport Headphones                1      99.99
# 19   295681            Wired Headphones                1      11.99
#
#         Order Date                           Purchase Address
# 0   12/30/19 00:01     136 Church St, New York City, NY 10001
# 1   12/29/19 07:03        562 2nd St, New York City, NY 10001
# 2   12/12/19 18:21       277 Main St, New York City, NY 10001
# 3   12/22/19 15:13        410 6th St, San Francisco, CA 94016
# 4   12/18/19 12:38              43 Hill St, Atlanta, GA 30301
# 5   12/31/19 22:58  200 Jefferson St, New York City, NY 10001
# 6   12/16/19 15:10            928 12th St, Portland, OR 97035
# 7   12/13/19 09:29           813 Hickory St, Dallas, TX 75001
# 8   12/15/19 23:26            718 Wilson St, Dallas, TX 75001
# 9   12/28/19 11:51                77 7th St, Dallas, TX 75001
# 10  12/13/19 13:52        594 1st St, San Francisco, CA 94016
# 11  12/28/19 17:19      410 Lincoln St, Los Angeles, CA 90001
# 12  12/20/19 19:19              866 Pine St, Boston, MA 02215
# 13  12/06/19 09:38           187 Lincoln St, Dallas, TX 75001
# 14  12/25/19 09:39               902 2nd St, Dallas, TX 75001
# 15  12/01/19 14:30              338 Main St, Austin, TX 73301
# 16  12/25/19 12:37                79 Elm St, Boston, MA 02215
# 17  12/25/19 12:37                79 Elm St, Boston, MA 02215
# 18  12/25/19 12:37                79 Elm St, Boston, MA 02215
# 19  12/25/19 12:37                79 Elm St, Boston, MA 02215

# %% [markdown]
# ### Convert columns to required Data type.

# %%
all_months_data['Quantity Ordered']= all_months_data['Quantity Ordered'].astype('int')
all_months_data['Price Each']= all_months_data['Price Each'].astype('float')

# %% [markdown]
# ### Augment data with additional columns

# %% [markdown]
# ### Task 2: Add Month Column

# %%
all_months_data['Month']= all_months_data[ 'Order Date'].str[0:2]
all_months_data['Month']= all_months_data['Month'].astype('int32')
all_months_data
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 0       295665      Macbook Pro Laptop                 1     1700.00
# 1       295666      LG Washing Machine                 1      600.00
# 2       295667    USB-C Charging Cable                 1       11.95
# 3       295668        27in FHD Monitor                 1      149.99
# 4       295669    USB-C Charging Cable                 1       11.95
# ...        ...                     ...               ...         ...
# 13617   222905  AAA Batteries (4-pack)                 1        2.99
# 13618   222906        27in FHD Monitor                 1      149.99
# 13619   222907    USB-C Charging Cable                 1       11.95
# 13620   222908    USB-C Charging Cable                 1       11.95
# 13621   222909  AAA Batteries (4-pack)                 1        2.99
#
#            Order Date                        Purchase Address  Month
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001     12
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001     12
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001     12
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016     12
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12
# ...               ...                                     ...    ...
# 13617  06/07/19 19:02           795 Pine St, Boston, MA 02215      6
# 13618  06/01/19 19:29   495 North St, New York City, NY 10001      6
# 13619  06/22/19 18:57   319 Ridge St, San Francisco, CA 94016      6
# 13620  06/26/19 18:35    916 Main St, San Francisco, CA 94016      6
# 13621  06/25/19 14:33          209 11th St, Atlanta, GA 30301      6
#
# [185950 rows x 7 columns]

# %% [markdown]
# ### What was the best month of sales? How much was earned that month?

# %% [markdown]
# #### Task 3: Add a sales column

# %%
all_months_data['sales']= all_months_data['Quantity Ordered']* all_months_data['Price Each']
all_months_data
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 0       295665      Macbook Pro Laptop                 1     1700.00
# 1       295666      LG Washing Machine                 1      600.00
# 2       295667    USB-C Charging Cable                 1       11.95
# 3       295668        27in FHD Monitor                 1      149.99
# 4       295669    USB-C Charging Cable                 1       11.95
# ...        ...                     ...               ...         ...
# 13617   222905  AAA Batteries (4-pack)                 1        2.99
# 13618   222906        27in FHD Monitor                 1      149.99
# 13619   222907    USB-C Charging Cable                 1       11.95
# 13620   222908    USB-C Charging Cable                 1       11.95
# 13621   222909  AAA Batteries (4-pack)                 1        2.99
#
#            Order Date                        Purchase Address  Month    sales
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001     12  1700.00
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001     12   600.00
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001     12    11.95
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   149.99
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12    11.95
# ...               ...                                     ...    ...      ...
# 13617  06/07/19 19:02           795 Pine St, Boston, MA 02215      6     2.99
# 13618  06/01/19 19:29   495 North St, New York City, NY 10001      6   149.99
# 13619  06/22/19 18:57   319 Ridge St, San Francisco, CA 94016      6    11.95
# 13620  06/26/19 18:35    916 Main St, San Francisco, CA 94016      6    11.95
# 13621  06/25/19 14:33          209 11th St, Atlanta, GA 30301      6     2.99
#
# [185950 rows x 8 columns]

# %%
results= all_months_data.groupby('Month').sum()
#results['Month'](results['sales'].max())
results['sales']
# Out:
# Month
# 1     1822256.73
# 2     2202022.42
# 3     2807100.38
# 4     3390670.24
# 5     3152606.75
# 6     2577802.26
# 7     2647775.76
# 8     2244467.88
# 9     2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months, results['sales'])
plt.show
plt.xticks(months)
plt.ylabel('Sales in USD($)')
plt.xlabel('Month number')
# Out:
# Text(0.5, 0, 'Month number')

# %% [markdown]
# ### what City had the highest number of sales?

# %% [markdown]
# ### add a city column

# %%
all_months_data['City']= all_months_data['Purchase Address'].apply(lambda x: x.split(',')[1]) + ' ' + '(' + (all_months_data['Purchase Address'].apply(lambda x: x.split(',')[2].split(' ')[1]))+')'

all_months_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month    sales  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12    11.95
#
#                   City
# 0   New York City (NY)
# 1   New York City (NY)
# 2   New York City (NY)
# 3   San Francisco (CA)
# 4         Atlanta (GA)

# %% [markdown]
# ### which city has the highest sales??

# %%
Total_sum_sales= all_months_data.groupby('City').sum()
Total_sum_sales.sort_values('sales',ascending = False)
# Out:
#                      Quantity Ordered  Price Each   Month       sales
# City
#  San Francisco (CA)             50239  8211461.74  315520  8262203.91
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Seattle (WA)                   16553  2733296.01  104941  2747755.48
#  Portland (OR)                  11303  1860558.22   70621  1870732.34
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Portland (ME)                   2750   447189.25   17144   449758.27

# %%
cities= [ city for city, df in all_months_data.groupby('City')]
plt.bar(cities, Total_sum_sales['sales'])
plt.xticks(cities, rotation='vertical',size = 11)

plt.xlabel('City Names')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# ### 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
all_months_data['Order Date']= pd.to_datetime(all_months_data['Order Date'])

# %%
all_months_data[ 'Hour'] = all_months_data['Order Date'].dt.hour
all_months_data[ 'Minute'] = all_months_data['Order Date'].dt.minute

all_months_data.sort_values(by=['Hour'], ascending=True)
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       295665        Macbook Pro Laptop                 1     1700.00
# 8748    231266          Wired Headphones                 1       11.99
# 7251    285731    AAA Batteries (4-pack)                 4        2.99
# 6072    147012           Vareebadd Phone                 1      400.00
# 13540   174937                    iPhone                 1      700.00
# ...        ...                       ...               ...         ...
# 16538   209827          Wired Headphones                 1       11.99
# 11593   270425  Apple Airpods Headphones                 1      150.00
# 6637    156836    AAA Batteries (4-pack)                 1        2.99
# 16490   209783     AA Batteries (4-pack)                 3        3.84
# 2374    261621     AA Batteries (4-pack)                 1        3.84
#
#                Order Date                          Purchase Address  Month  \
# 0     2019-12-30 00:01:00    136 Church St, New York City, NY 10001     12
# 8748  2019-07-26 00:24:00           947 Church St, Dallas, TX 75001      7
# 7251  2019-12-01 00:02:00      786 Hill St, San Francisco, CA 94016     12
# 6072  2019-01-23 00:48:00  975 Lakeview St, San Francisco, CA 94016      1
# 13540 2019-03-23 00:26:00             284 14th St, Austin, TX 73301      3
# ...                   ...                                       ...    ...
# 16538 2019-05-17 23:32:00    391 Spruce St, San Francisco, CA 94016      5
# 11593 2019-10-10 23:17:00    292 Highland St, Los Angeles, CA 90001     10
# 6637  2019-02-14 23:15:00              18 4th St, Seattle, WA 98101      2
# 16490 2019-05-14 23:26:00      859 Pine St, San Francisco, CA 94016      5
# 2374  2019-10-31 23:18:00    959 Willow St, New York City, NY 10001     10
#
#          sales                 City  Hour  Minute
# 0      1700.00   New York City (NY)     0       1
# 8748     11.99          Dallas (TX)     0      24
# 7251     11.96   San Francisco (CA)     0       2
# 6072    400.00   San Francisco (CA)     0      48
# 13540   700.00          Austin (TX)     0      26
# ...        ...                  ...   ...     ...
# 16538    11.99   San Francisco (CA)    23      32
# 11593   150.00     Los Angeles (CA)    23      17
# 6637      2.99         Seattle (WA)    23      15
# 16490    11.52   San Francisco (CA)    23      26
# 2374      3.84   New York City (NY)    23      18
#
# [185950 rows x 11 columns]

# %%
hours = [hour for hour, df in all_months_data.groupby('Hour')]
y= all_months_data.groupby(['Hour']).count()
plt.plot(hours,y['Order Date'])
plt.xticks(hours)
plt.grid()
plt.show()

# %% [markdown]
# ### 11:00 to 12:00 and 19:00 is better time.

# %% [markdown]
# ### What products are most often sold together??

# %%
sell= all_months_data[all_months_data['Order ID'].duplicated(keep= False)]

sell['Grouped']= sell.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

sell= sell[['Order ID', 'Grouped']].drop_duplicates()
sell.head(50)
# Out:
# /var/folders/xg/g1wspk597n71rp310cb20lbh0000gn/T/ipykernel_87156/7162551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sell['Grouped']= sell.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#      Order ID                                            Grouped
# 16     295681  Google Phone,USB-C Charging Cable,Bose SoundSp...
# 36     295698               Vareebadd Phone,USB-C Charging Cable
# 42     295703   AA Batteries (4-pack),Bose SoundSport Headphones
# 66     295726                    iPhone,Lightning Charging Cable
# 76     295735   iPhone,Apple Airpods Headphones,Wired Headphones
# 80     295737                    iPhone,Lightning Charging Cable
# 97     295753    34in Ultrawide Monitor,Lightning Charging Cable
# 104    295759        Bose SoundSport Headphones,Wired Headphones
# 129    295783               Vareebadd Phone,USB-C Charging Cable
# 133    295786      USB-C Charging Cable,Apple Airpods Headphones
# 141    295793                  Google Phone,USB-C Charging Cable
# 166    295817                  USB-C Charging Cable,20in Monitor
# 172    295822                      Google Phone,Wired Headphones
# 180    295829                  Google Phone,USB-C Charging Cable
# 272    295918       AA Batteries (4-pack),AAA Batteries (4-pack)
# 287    295932  Apple Airpods Headphones,Bose SoundSport Headp...
# 308    295952                 USB-C Charging Cable,Flatscreen TV
# 348    295991                    iPhone,Lightning Charging Cable
# 439    296081                        Flatscreen TV,Flatscreen TV
# 494    296135     AA Batteries (4-pack),Lightning Charging Cable
# 501    296141  Lightning Charging Cable,Bose SoundSport Headp...
# 505    296144                    iPhone,Apple Airpods Headphones
# 514    296152      USB-C Charging Cable,Lightning Charging Cable
# 550    296187                  Google Phone,USB-C Charging Cable
# 627    296263                      Google Phone,Wired Headphones
# 632    296267             Flatscreen TV,Lightning Charging Cable
# 642    296276               Vareebadd Phone,USB-C Charging Cable
# 723    296353  iPhone,Lightning Charging Cable,Wired Headphon...
# 727    296354               Vareebadd Phone,USB-C Charging Cable
# 764    296390                            iPhone,Wired Headphones
# 817    296442                  Google Phone,USB-C Charging Cable
# 819    296443         Vareebadd Phone,Bose SoundSport Headphones
# 821    296444        AAA Batteries (4-pack),USB-C Charging Cable
# 898    296520                  Google Phone,USB-C Charging Cable
# 910    296531        27in FHD Monitor,Bose SoundSport Headphones
# 954    296574                            iPhone,Wired Headphones
# 990    296609                  Google Phone,USB-C Charging Cable
# 1023   296641                            iPhone,Wired Headphones
# 1036   296653                      Google Phone,Wired Headphones
# 1052   296668      AAA Batteries (4-pack),AAA Batteries (4-pack)
# 1055   296670               Vareebadd Phone,USB-C Charging Cable
# 1073   296687    Lightning Charging Cable,27in 4K Gaming Monitor
# 1094   296707          Apple Airpods Headphones,Wired Headphones
# 1119   296730            27in 4K Gaming Monitor,Wired Headphones
# 1187   296797                   Macbook Pro Laptop,Flatscreen TV
# 1195   296804     Lightning Charging Cable,AA Batteries (4-pack)
# 1233   296841                            iPhone,Wired Headphones
# 1243   296850  Bose SoundSport Headphones,AAA Batteries (4-pack)
# 1250   296856          Lightning Charging Cable,27in FHD Monitor
# 1295   296900                   Vareebadd Phone,Wired Headphones

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in sell['Grouped']:
    row_list= row.split(',')
    count.update(Counter(combinations(row_list,2)))
    

count.most_common(10)

for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### What products sold the most? and why?

# %%
Product_group= all_months_data.groupby('Product')
Quantity_ordered= Product_group.sum()['Quantity Ordered']

products= [product for product, df in Product_group]
plt.bar(products, Quantity_ordered)

plt.xticks(products, rotation= 'vertical', size= 8)
plt.xlabel('Products')
plt.ylabel('Quantity ordered')
plt.show()

# %%
prices = all_months_data.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots ()
ax2 = ax1.twinx ()
ax1.bar(products, Quantity_ordered,color= 'g') 
ax2.plot(products, prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color= 'g')
ax2.set_ylabel(',Price ($)', color='b')
ax1.set_xticklabels(products, rotation= 'vertical', size= 8)
plt.show()
# Out:
# /var/folders/xg/g1wspk597n71rp310cb20lbh0000gn/T/ipykernel_87156/2003849370.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation= 'vertical', size= 8)

# %% [markdown]
# ### Low price products are sold more and products like Macbooks are sold more because of reqiurements and Students, etc.
